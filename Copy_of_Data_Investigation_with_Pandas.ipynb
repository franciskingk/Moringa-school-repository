# %% [markdown]
# <a href="https://colab.research.google.com/github/franciskingk/Moringa-school-repository/blob/main/Copy_of_Data_Investigation_with_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="green">*To start working on this notebook, or any other notebook that we will use in the Moringa Data Science Course, we will need to save our own copy of it. We can do this by clicking File > Save a Copy in Drive. We will then be able to make edits to our own copy of this notebook.*</font>

# %% [markdown]
# # Data Investigation with Pandas

# %% [markdown]
# ## 1.0 Importing our Libraries

# %%
# Importing the libraries we will need 

# Importing the pandas library
# 
import pandas as pd

# Importing the numpy library
#
import numpy as np

# %% [markdown]
# ## 1.1 Reading the Dataset from our CSV file

# %% [markdown]
# The dataset we will use contains information about the 2009 Census - The Rural Urban Population by Age, Sex and District.
#
#
# *   Dataset link for download or access: [Link](https://drive.google.com/open?id=1pc9ZLFGsosdWBk1lI29ADIqRtCvD_FBe)

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# 
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-aaabaed7-0cf8-4eab-a219-4bced1a2ed1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aaabaed7-0cf8-4eab-a219-4bced1a2ed1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Rural_Urban_Population_By_Age_Sex_and_by_District__2009.csv to Rural_Urban_Population_By_Age_Sex_and_by_District__2009 (1).csv
# {'Rural_Urban_Population_By_Age_Sex_and_by_District__2009.csv': b"\xef\xbb\xbfDistrict,Urban/Rural,Age_years,Male,Female,Total,County,Province,OBJECTID\nNAIROBI WEST,Urban,0,10126,10116,20242,Nairobi,NAIROBI,0\nNAIROBI WEST,Urban,1,8124,7989,16113,Nairobi,NAIROBI,1\nNAIROBI WEST,Urban,2,8462,8627,17089,Nairobi,NAIROBI,2\nNAIROBI WEST,Urban,3,8334,8420,16754,Nairobi,NAIROBI,3\nNAIROBI WEST,Urban,4,7948,7820,15768,Nairobi,NAIROBI,4\nNAIROBI WEST,Urban,5,7547,7660,15207,Nairobi,NAIROBI,5\nNAIROBI WEST,Urban,6,6966,7082,14048,Nairobi,NAIROBI,6\nNAIROBI WEST,Urban,7,6511,6674,13185,Nairobi,NAIROBI,7\nNAIROBI WEST,Urban,8,6171,6489,12660,Nairobi,NAIROBI,8\nNAIROBI WEST,Urban,9,6361,6662,13023,Nairobi,NAIROBI,9\nNAIROBI WEST,Urban,10,6440,6592,13032,Nairobi,NAIROBI,10\nNAIROBI WEST,Urban,11,4907,5260,10167,Nairobi,NAIROBI,11\nNAIROBI WEST,Urban,12,5717,5998,11715,Nairobi,NAIROBI,12\nNAIROBI WEST,Urban,13,5442,5763,11205,Nairobi,NAIROBI,13\nNAIROBI WEST,Urban,14,4956,5193,10149,Nairobi,NAIROBI,14\nNAIROBI WEST,Urban,15,4630,5384,10014,Nairobi,NAIROBI,15\nNAIROBI WEST,Urban,16,4686,5690,10376,Nairobi,NAIROBI,16\nNAIROBI WEST,Urban,17,5396,6580,11976,Nairobi,NAIROBI,17\nNAIROBI WEST,Urban,18,5914,7810,13724,Nairobi,NAIROBI,18\nNAIROBI WEST,Urban,19,5891,7942,13833,Nairobi,NAIROBI,19\nNAIROBI WEST,Urban,20,8128,11795,19923,Nairobi,NAIROBI,20\nNAIROBI WEST,Urban,21,7348,9257,16605,Nairobi,NAIROBI,21\nNAIROBI WEST,Urban,22,9543,11537,21080,Nairobi,NAIROBI,22\nNAIROBI WEST,Urban,23,10187,11374,
airobi,NAIROBI,58\nNAIROBI WEST,Urban,59,861,571,1432,Nairobi,NAIROBI,59\nNAIROBI WEST,Urban,60,1342,926,2268,Nairobi,NAIROBI,60\nNAIROBI WEST,Urban,61,606,396,1002,Nairobi,NAIROBI,61\nNAIROBI WEST,Urban,62,643,402,1045,Nairobi,NAIROBI,62\nNAIROBI WEST,Urban,63,533,354,887,Nairobi,NAIROBI,63\nNAIROBI WEST,Urban,64,472,378,850,Nairobi,NAIROBI,64\nNAIROBI WEST,Urban,65,631,462,1093,Nairobi,NAIROBI,65\nNAIROBI WEST,Urban,66,309,267,576,Nairobi,NAIROBI,66\nNAIROBI WEST,Urban,67,358 ...

# %% [markdown]
# ## 1.2 Previewing our Dataset

# %%
# Let's preview the first 10 rows of our data
# 
df= pd.read_csv('/content/Rural_Urban_Population_By_Age_Sex_and_by_District__2009.csv')
df
# Out:
#            District Urban/Rural Age_years  ...   County  Province  OBJECTID
# 0      NAIROBI WEST       Urban         0  ...  Nairobi   NAIROBI         0
# 1      NAIROBI WEST       Urban         1  ...  Nairobi   NAIROBI         1
# 2      NAIROBI WEST       Urban         2  ...  Nairobi   NAIROBI         2
# 3      NAIROBI WEST       Urban         3  ...  Nairobi   NAIROBI         3
# 4      NAIROBI WEST       Urban         4  ...  Nairobi   NAIROBI         4
# ...             ...         ...       ...  ...      ...       ...       ...
# 25415    TESO SOUTH       Rural        77  ...    Busia   WESTERN     25415
# 25416    TESO SOUTH       Rural        78  ...    Busia   WESTERN     25416
# 25417    TESO SOUTH       Rural        79  ...    Busia   WESTERN     25417
# 25418    TESO SOUTH       Rural       80+  ...    Busia   WESTERN     25418
# 25419    TESO SOUTH       Rural    Age NS  ...    Busia   WESTERN     25419
#
# [25420 rows x 9 columns]

# %% [markdown]
# ## 1.3 Accessing Information about our Dataset

# %%
# We can getting to know more about the dataset by accessing its information 
#
type("OBJECTID")
# Out:
# str

# %% [markdown]
# ## 1.4 Answering Questions

# %% [markdown]
# Let's answer the following questions with our dataset

# %%
df.loc[df['Age_years'] == '80+', 'Age_years']= 80
df.loc[df['Age_years'] == 'Age NS', 'Age_years']= 90

# %%
# Challenge 1
# What was the average age of a person of Kenya?
#
df["Age_years"]= pd.to_numeric(df["Age_years"])
df['Age_years'].mean()
# Out:
# 40.609756097560975

# %%
# Challenge 2
# What was the average female population in Kenya?
#
df_mean = df["Female"].mean()
print(df_mean)
# Out:
# 763.8725019669552

# %%
# Challenge 3
# What was the average male population in Kenya?
#
df_mean = df["Male"].mean()
print(df_mean)
# Out:
# 755.0140833988985

# %%
# Challenge 4
# Which 5 districts were the most densely populated Kenya in descending order?
#
x=df.groupby('District').sum()['Total'].sort_values(ascending=False)
x
# Out:
# District
# NAIROBI EAST      1144416
# NAIROBI NORTH     1062086
# NAIROBI WEST       684765
# SIAYA              550224
# MOLO               542103
#                    ...
# SAMBURU NORTH       59801
# SAMBURU EAST        59094
# MARSABIT            46502
# GARBATULLA          43118
# LAIKIPIA NORTH      32762
# Name: Total, Length: 158, dtype: int64

# %%
# Challenge 5
# Which 5 counties were the most densely populated Counties in descending order?
# 
y= df.groupby('County').count()['Total']
most=y.sort_values(ascending = False)
most
# Out:
# County
# Kiambu             1476
# Meru               1148
# Kakamega           1148
# Kisii               820
# Bungoma             820
# Busia               820
# Nandi               820
# Kitui               656
# Migori              656
# Makueni             656
# Machakos            656
# Nakuru              656
# Baringo             656
# Wajir               656
# Garissa             656
# Marsabit            656
# Kisumu              492
# Kwale               492
# Kilifi              492
# Laikipia            492
# Kajiado             492
# Homa Bay            492
# Bomet               492
# West Pokot          492
# Mandera             492
# Vihiga              492
# Uasin Gishu         492
# Narok               492
# Nyamira             492
# Turkana             492
# Samburu             492
# Siaya               492
# Murang'a            492
# Trans Nzoia         492
# Isiolo              328
# Elgeyo Marakwet     328
# Embu                328
# Kericho             328
# Tana River          328
# Taita Taveta        328
# Nyeri               328
# Nyandarua           328
# Nairobi             328
# Tharaka Nithi       164
# Kirinyaga           164
# Lamu                164
# Mombasa             164
# Name: Total, dtype: int64

# %%
# Challenge 6
# Which 5 districts were the most sparsely populated in descending order?
# 
least=df.groupby(['District']).count()["Total"]
least_pop=least.sort_values(ascending = False)

least_pop.head(5)
# Out:
# District
# YATTA          164
# KILIFI         164
# KISUMU WEST    164
# KISUMU EAST    164
# KISII SOUTH    164
# Name: Total, dtype: int64

# %%
# Challenge 7
# What was the average population of the the most densely populated county in Kenya?
# 
df.loc[(df['County']== 'Kiambu')].mean()
# Out:
# Age_years      40.609756
# Male          560.840108
# Female        573.160569
# Total        1134.000678
# OBJECTID     7593.510163
# dtype: float64

# %%
# Challenge 8
# What was the average population of the the most sparsely populated county in Kenya?
# 
df.loc[(df['County']== 'Baringo')].mean()['Total']
# Out:
# 846.891768292683

# %%
# Challenge 9
# What was the total population of Busia County? 
# 
df.loc[(df['County'] == 'Busia')].sum()['Total']
# Out:
# 743946

# %%
# Challenge 10
# What was the average age of person in Busia County? How many people of this age were in Busia County?
# 
df.loc[(df['County'] == 'Busia')].mean()['Age_years']
# Out:
# 40.609756097560975

# %%
# Challenge 11
# What was the Total population of Teso South District?
# 
df.loc[(df['District'] == 'TESO SOUTH')].sum()['Age_years']
# Out:
# 6660

# %%
# Challenge 12
# What was the urban population of Teso South District?
# 
df.loc[(df["District"]=="TESO SOUTH")&(df["Urban/Rural"]=="Urban")]["Total"].sum()
# Out:
# 26162

# %%
# Challenge 13
# What was the rural population of Teso South District?
# 
df.loc[(df["District"]=="TESO SOUTH")&(df["Urban/Rural"]=="Rural")]["Total"].sum()
# Out:
# 111762

# %%
# Challenge 14
# What was the population of people aged 60 and above in Kenya?
#
df.loc[(df["Age_years"]>60)].sum()["Total"]
# Out:
# 1709703

# %%
# Challenge 15 
# What was the urban population in Kenya?
#
df.loc[(df['Urban/Rural']=="Urban")].sum()["Total"]
# Out:
# 12487375
